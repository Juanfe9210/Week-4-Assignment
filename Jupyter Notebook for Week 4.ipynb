# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# __Juan Felipe Zambrano__
#
# Hydraulic Engineer

# %% [markdown]
# _I am interested in data science because really like to know about how I can get better tools and solutions using this methods on my profession_

# %% [markdown]
# ### This code simply prints the phrase _Course Finished!!_ by join different strings variables

# %%
##Print

A = "Course"
B = "Finished"
C= "!!"

print(A+" "+B+C)
# Out:
# Course Finished!!

# %% [markdown]
# ### The Course Tools for Data Science teachs you the different tools and options that Data Sicentist, Engineers or Enthusiasts are going to use
# - - -
# You can access to the course by clicking [here](https://www.coursera.org/learn/open-source-tools-for-data-science/home/welcome)
# - - -
# The course is divided in 4 weeks:
#
# - Week 1: Data Scientist's Toolkit
# - Week 2: Open Source Tools
# - Week 3: IBM Tools for Data Science
# - Week 4: Final Assignment
#
# ![IBM-Logo-Blk---Square.png](attachment:IBM-Logo-Blk---Square.png)
